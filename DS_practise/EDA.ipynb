# %%
import matplotlib.pyplot as plt

y1 = []
y2 = []
x = range(-100, 100, 10)
for i in x:
   y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)

plt.xlabel('x')
plt.ylabel('y')
plt.title('simple graph')
plt.show()

# %%
import matplotlib.pyplot as plt

y1 = []
y2 = []
x = range(-100, 100, 10)
for i in x:
   y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('simple graph')
plt.axvline(x=0)
plt.show()

# %%
import matplotlib.pyplot as plt

y1 = []
y2 = []
x = range(-100, 100, 10)
for i in x:
   y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('simple graph')
plt.axhline(y=0)
plt.show()

# %%
import matplotlib.pyplot as plt

y1 = []
y2 = []
x = range(-100, 100, 10)
for i in x:
   y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('simple graph')
plt.axvline(x=0, color='r')
plt.axhline(y=0, color='g')
plt.show()

# %%
import matplotlib.pyplot as plt

y1 = []
y2 = []
x = range(-100, 100, 10)
for i in x:
   y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('simple graph')
plt.axvline(x=0, color='r')
plt.axhline(y=0, color='g')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('simple graph')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('simple graph')
plt.show()
df
# Out:
#             Mes  data science  machine learning  deep learning  categorical
# 0    2004-01-01            12                18              4            1
# 1    2004-02-01            12                21              2            1
# 2    2004-03-01             9                21              2            1
# 3    2004-04-01            10                16              4            1
# 4    2004-05-01             7                14              3            1
# ..          ...           ...               ...            ...          ...
# 189  2019-10-01            90                98             98            0
# 190  2019-11-01            87                97             96            0
# 191  2019-12-01            81                89             91            0
# 192  2020-01-01            94                94             93            1
# 193  2020-02-01           100                99             99            1
#
# [194 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('simple graph')
plt.grid(True)
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs) -> 'Legend'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('simple graph')
plt.grid(False)
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs) -> 'Legend'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.plot(df['deep learning'],color='orange')
plt.plot(df['machine learning'],color='green')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('simple graph')
plt.grid(True)
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs) -> 'Legend'>

# %%
import matplotlib.pyplot as plt
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]
plt.scatter(x_values,y_values, s=30, color='aquamarine')
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]
plt.scatter(x_values,y_values, s=30, color='aquamarine', marker="^")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('My scatter plot!')
plt.show()
# Out:
# /tmp/ipykernel_659/2702576863.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]
plt.scatter(x_values,y_values, s=30, color='aquamarine', marker="^")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('My scatter plot!')
plt.legend()
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_659/2636052584.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]
plt.scatter(df['deep learning'], df['data science'], s=30, color='aquamarine', marker="^")
plt.xlabel('deep learning')
plt.ylabel('data science')
plt.title('Scatter')
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]
plt.scatter(df['deep learning'], df['data science'], s=30, color='aquamarine', marker="^")
plt.xlabel('deep learning')
plt.ylabel('data science')
plt.title('Scatter')
plt.legend()
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_659/3445426497.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
values = [5, 6, 3, 7, 2]
names = ['A', 'B', 'C', 'D', 'E']
plt.bar(names, values, color='aquamarine')
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5, 6, 3, 7, 2]
names = ['A', 'B', 'C', 'D', 'E']
plt.barh(names, values, color='aquamarine')
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5, 6, 3, 7, 2]
names = ['A', 'B', 'C', 'D', 'E']
c1=['aqua','aquamarine']
c2=['b','g']
plt.bar(names, values, width=0.8, color=c1)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('My bar chart!')
plt.show()
